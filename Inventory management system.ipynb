# %% [markdown]
# ###Inventory Management System

# %%
import json
fd = open("Products.json",'w')

products = {
  1000 : {"name" : "CRACKING the CODING INTERVIEW", "price" : 599, "discount" : 5, "weight" : 400, "category" : "Book", "quantity" : 100, "location" : "India", "status" : "active"},
  1001 : {"name" : "Crack GATE", "price" : 700, "discount" : 10, "weight" : 500, "category" : "Book", "quantity" : 50, "location" : "India", "status" : "active"},
  1002 : {"name" : "Paracetamol", "price" : 4, "discount" : 50, "weight" : 5, "category" : "Medicine", "quantity" : 200, "location" : "India", "status" : "active"},
  1003 : {"name" : "N95 mask", "price" : 1099, "discount" : 86, "weight" : 5, "category" : "Respirator", "quantity" : 1000, "location" : "India", "status" : "active"},
  1004 : {"name" : "Smartphone Back cover", "price" : 699, "discount" : 72, "weight" : 10, "category" : "Back cover", "quantity" : 99, "location" : "India", "status" : "active"},
  1005 : {"name" : "A-Star Electric Toaster", "price" : 1870, "discount" : 32, "weight" : 1000, "category" : "Electric Toaster", "quantity" : 299, "location" : "India", "status" : "active"},
  1006 : {"name" : "Realme X5 5G", "price" : 2000, "discount" : 10, "weight" : 50, "category" : "Earphone", "quantity" : 100, "location" : "India", "status" : "active"},
  1007 : {"name" : "Boat Bassheads 225", "price" : 2190, "discount" : 8, "weight" : 70, "category" : "Earphone", "quantity" : 200, "location" : "India", "status" : "active"},
  1008 : {"name" : "Himalaya Face Wash", "price" : 225, "discount" : 10, "weight" : 100, "category" : "Beauty", "quantity" : 50, "location" : "India", "status" : "active"},
  1009 : {"name" : "Building Materials", "price" : 686, "discount" : 52, "weight" : 250, "category" : "Book", "quantity" : 20, "location" : "India", "status" : "active"},
  1010 : {"name" : "Ambrane 1000 mAh Power Bank", "price" : 1199,  "discount" : 25, "weight" : 240, "category" : "Electronics", "quantity" : 500, "location" : "India", "status" : "active"},
  1011 : {"name" : "XT-77 2000 mAh Power Bank", "price" : 2199,  "discount" : 22, "weight" : 434, "category" : "Electronics", "quantity" : 1000, "location" : "India", "status" : "active"},
  1012 : {"name" : "SanDisk 64GB PenDrive", "price" : 926, "discount" : 35, "weight" : 10, "category" : "Electronics", "quantity" : 99, "location" : "India", "status" : "active"},
  1013 : {"name" : "Logitech Wireless Keyboard", "price" : 1095, "discount" : 18, "weight" : 480, "category" : "Laptop Keyboard", "quantity" : 149, "location" : "India", "status" : "active"},
  1014 : {"name" : "HP X3500 Wireless Comfort Mouse", "price" : 877, "discount" : 20, "weight" : 95, "category" : "RevenX Computer Mouse", "quantity" : 5, "location" : "India", "status" : "active"},
  1015 : {"name" : "PHILIPS QT4909S Trimmer", "price" : 2375, "discount" : 32, "weight" : 340, "category" : "Corded & Cordless", "quantity" : 9, "location" : "India", "status" : "active"},
  1016 : {"name" : "Lenove IdeaPad Gaming 3(16 GB/1TB GB SSD/Windows 10/4GB Graphics)", "price" : 89000, "discount" : 35, "weight" : 2100, "category" : "Gaming Laptop", "quantity" : 20, "location" : "India", "status" : "active"},
  1017 : {"name" : "SONY SRS-XB13 Bluetooth Speaker(Blue)", "price" : 4990, "discount" : 20, "weight" : 100, "category" : "Speaker", "quantity" : 20, "location" : "India", "status" : "active"},
  1018 : {"name" : "SAMSUNG Galaxy M31(6 GB/64 GB)", "price" : 17500, "discount" : 8, "weight" : 191, "category" : "Mobile", "quantity" : 55, "location" : "India", "status" : "active"},
  1019 : {"name" : "POCO M2 Pro(6 GB/128 GB)", "price" : 1999, "discount" : 20, "weight" : 209, "category" : "Mobile", "quantity" : 13, "location" : "India", "status" : "active"},
  1020 : {"name" : "Realme Narzo 30 Pro 5 GB(6 GB/64 GB)", "price" : 18999, "discount" : 15, "weight" : 194, "category" : "Mobile", "quantity" : 2, "location" : "India", "status" : "active"},
  1021 : {"name" : "APPLE iPhone 12 Pro", "price" : 129900, "discount" : 3, "weight" : 5, "category" : "Mobile", "quantity" : 5, "location" : "India", "status" : "active"},
  1022 : {"name" : "APPLE Macmini", "price" : 122900, "discount" : 8, "weight" : 1400, "category" : "Laptops", "quantity" : 7, "location" : "India", "status" : "active"},
  1023 : {"name" : "boAt Xtend Smartwatch with Alexa Built-in", "price" : 7990, "discount" : 56, "weight" : 200, "category" : "Smart Watch", "quantity" : 19, "location" : "India", "status" : "active"},
  1024 : {"name" : "Kids cloth", "price" : 500, "discount" : 20, "weight" : 300, "category" : "cloth", "quantity" : 13, "location" : "India", "status" : "active"},
  1025 : {"name" : "Milton Duo Delux 1000 Thermosteel 24 hour cold water bottle", "price" : 1200, "discount" : 15, "weight" : 500, "category" : "Water Bottle", "quantity" : 13, "location" : "India", "status" : "active"},
  1026 : {"name" : "Anticirus CD", "price" : 900, "discount" : 10, "weight" : 20, "category" : "Software", "quantity" : 100, "location" : "India", "status" : "active"},
  1027 : {"name" : "American Tourister Jamaica Polyester Suitcase", "price" : 10800, "discount" : 60, "weight" : 4100, "category" : "Traveling bag", "quantity" : 39, "location" : "India", "status" : "active"},
  1028 : {"name" : "Shoe(Men/Women)", "price" : 2000, "discount" : 60, "weight" : 500, "category" : "Shoe", "quantity" : 63, "location" : "India", "status" : "active"},
  1029 : {"name" : "Amazon Basica 80cm (32 inch) HD Android TV", "price" : 27000, "discount" : 45, "weight" : 3000, "category" : "TV", "quantity" : 83, "location" : "India", "status" : "active"},
  1030 : {"name" : "OnePlus 80 cm (32 inch) Y series HD Android TV", "price" : 19999, "discount" : 5, "weight" : 3000, "category" : "TV", "quantity" : 13, "location" : "India", "status" : "active"},
  1031 : {"name" : "Logitech B170 Wireless Mouse, 2.4 GHz with USB Reciever", "price" : 795, "discount" : 20, "weight" : 95, "category" : "Electronics", "quantity" : 3, "location" : "India", "status" : "active"},
  1032 : {"name" : "Samsung Pro QLED (65 inch) Premium 4k TV", "price" : 199999, "discount" : 10, "weight" : 5000, "category" : "TV", "quantity" : 19, "location" : "India", "status" : "active"},
  1033 : {"name" : "Macbook Air Pro(16 Inch) M1 Chip", "price" : 299999, "discount" : 5, "weight" : 1200, "category" : "Electronics", "quantity" : 10, "location" : "India", "status" : "active"}
  }

prod = json.dumps(products)
fd.write(prod) 
fd.close()

with open("Products.json") as fd:
  products = json.loads(fd.read())

def Product_Details():
  prod_num = 1
  print(" Item number","      Item name")
  print("--------------"," ----------------")
  for product in products:
    print("  ",prod_num,"            ",products[product]["name"])
    prod_num += 1
  print("\n---------------------------------------------------------------------------------------------------")

def Display():
  print("Welcome to PowerX Inventory Management System\n")

 
def IO():
  option = input("Do you want to buy any product (say 'yes' or 'no')                   : ")
  option = option.lower()
  if option == 'no':
    print("Thanks for visiting PowerX Inventory Management System")
  elif option == 'yes':
    prod_num = int(input("Select product number associated with product name (ex: 1,2,3,.....) : "))
    Check_Product_Availability(prod_num)

def Check_Product_Availability(prod_num):
  if prod_num <= 10:
    prod_num = "100" + str(prod_num - 1) 
  else:
    prod_num = "10" + str(prod_num - 1)
  
  status = products[prod_num]["status"]

  if status == 'deactive':
    print(products[prod_num]["name"],"is Not Available")
  else:
    num_of_item = int(input("Enter number of items to buy                                     : "))
    quantity = products[prod_num]["quantity"]
    if quantity < num_of_item:
      print("\n*******************************************************")
      print("*   Warning :   Currently",quantity,"item is available       *")
      print("*                                                     *")
      print("*******************************************************\n")
      answer = input("Do yo need only "+str(quantity)+" item  (type 'yes' or 'no')                        : ")

      if answer.lower() == 'no':
        print("Thanks for usning PowerX Inventory Management System")
      else:
        Bill_Generator(prod_num, quantity)
        update_quantity(prod_num, quantity)

    else:
      Bill_Generator(prod_num, num_of_item)
      update_quantity(prod_num, num_of_item)

def update_quantity(prod_no, quantity):
  products[prod_no]["quantity"] = products[prod_no]["quantity"] - quantity
  if products[prod_no]["quantity"] == 0:
    products[prod_no]["status"] = 'deactive'
  with open("Products.json", mode = 'w', encoding = 'utf-8') as fd:
    js = json.dumps(products)
    fd.write(js)

def Bill_Generator(prod_num, quantity):
  discount = products[prod_num]["price"] * products[prod_num]["discount"] / 100
  final_price = int(quantity * (products[prod_num]["price"] - discount))
  total_discount = quantity * (products[prod_num]["price"]) - final_price
  print("\n\n_________________________________________________________________________________________")
  print("                    Cash Reciept                                                       ")
  print("     *********************************************************************                  ")
  print("         Item name        :",products[prod_num]["name"],"                             ")
  print("         Category         :",products[prod_num]["category"],"                                                      ")
  print("         No. of item      :",quantity,"                                                         ")
  print("         Price            :",products[prod_num]["price"],"                                                       ")
  print("         Discount         :",str(products[prod_num]["discount"])+"%","                                                        ")
  print("         Weight of item :",str(products[prod_num]["weight"])+"gm","                                                     ")
  print("     *********************************************************************                  ")
  print("               TOTAL PAYABLE(in rupees)  ="," "+str(final_price),"                                      ")
  print("               You save(in rupees)       ="," "+str(total_discount),"                                       ")

  print("_________________________________________________________________________________________")
Product_Details()
Display()
IO()
